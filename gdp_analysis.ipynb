# %%
import os, sys
os.chdir("/Users/chloe_wxy/Desktop/D100/FED_EX2")
sys.path.append("/Users/chloe_wxy/Desktop/D100/FED_EX2")

from fed.data import load_gdp_data, save_clean_data
from fed.plot_utils import plot_gdp_trend

print("✅ Functions imported successfully!")
# Out:
# ✅ Functions imported successfully!

# %%
df = load_gdp_data()
save_clean_data(df)
df.head()
# Out:
# Loaded 115 rows of GDP data (in Trillions of USD).
# ✅ Clean data saved to gdp_clean.csv
#   country_name  year  gdp_trillion_usd
# 0  Switzerland  2022          0.828509
# 1  Switzerland  2021          0.815309
# 2  Switzerland  2020          0.741999
# 3  Switzerland  2019          0.721369
# 4  Switzerland  2018          0.725569

# %%
from fed.plot_utils import plot_gdp_trend
plot_gdp_trend("gdp_clean.csv")
# Out:
# 📊 Loaded columns: ['country_name', 'year', 'gdp_trillion_usd']
